# %% [markdown]
# DATA SCIENCE INTERN AT LETSGROWMORE LGMVIPDECEMBER NAME: AVISHKAR DIGE TASK 4 : Image to pencil sketch with Python

# %%
import cv2
from IPython.display import Image
import ipyplot
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
image = cv2.imread("Arthur.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.title("RGB image")
plt.show()
# image = cv2.resize(image_og, (0, 0), fx=0.3, fy=0.3)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_image)
plt.title("Gray image")
plt.show()

# %%
inverted_image = 255 - gray_image
plt.imshow(inverted_image)
plt.title("Inverted image")
plt.show()

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
plt.imshow(cv2.cvtColor(pencil_sketch, cv2.COLOR_BGR2RGB))
plt.title("Pencil sketch")
plt.show()
